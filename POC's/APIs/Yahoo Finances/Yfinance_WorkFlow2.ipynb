# %%
# Importing necessory libaraies
import yfinance as yf
from datetime import datetime

# %%
# API for collecting stock data according to company using YFinance
def get_stock_data(company_name,
                   start_date):
    end_date = datetime.now()
    stock_data = yf.download(tickers=company_name, 
                             start=start_date, 
                             end=end_date, 
                             interval='1h')
    return stock_data

# %%
# Sending input data for getting stock data
c_name = 'IBM'
s_date = '2021-01-01'

IBM_data = get_stock_data(c_name,
                          s_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
IBM_data
# Out:
#                                  Open        High         Low       Close  \
# 2021-01-04 09:30:00-05:00  120.315491  120.379921  118.938812  119.201721
# 2021-01-04 10:30:00-05:00  119.197899  119.311661  117.767685  118.312622
# 2021-01-04 11:30:00-05:00  118.288719  118.326958  117.734222  118.049713
# 2021-01-04 12:30:00-05:00  118.049713  118.451241  117.629066  118.262146
# 2021-01-04 13:30:00-05:00  118.260040  118.508606  117.992355  118.135757
# ...                               ...         ...         ...         ...
# 2022-09-27 11:30:00-04:00  122.404999  122.680000  121.809998  122.294800
# 2022-09-27 12:30:00-04:00  122.290001  122.590698  121.830002  121.930000
# 2022-09-27 13:30:00-04:00  121.849998  121.989998  121.080002  121.297501
# 2022-09-27 14:30:00-04:00  121.290001  121.949997  121.099998  121.779999
# 2022-09-27 15:30:00-04:00  121.779999  121.879997  121.449997  121.750000
#
#                             Adj Close  Volume
# ...
